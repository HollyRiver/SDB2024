# %% [markdown]
# * 데이터베이스의 정의와 네 가지 데이터 정의
#
# * 데이터베이스의 네 가지 특징
#
# * 범주형 데이터에서 성별은 (  )형이며, 학점은 (  )형이다.
#
# * 파일의 구조가 바뀌면 응용프로그램도 함께 변경해야 한다면 이는 데이터의 (    )에 문제가 있다고 할 수 있다.
#
# * 사용자의 요구에 따라 데이터에 접근하고, 삽입/삭제/수정/검색을 위한 데이터 언어를 데이터(    )라고 한다.
#
# * 데이터베이스 관리시스템은 (        )라는 장점과, (        )하다는 단점이 있다.
#
# * 대체로 4단계로 구분되는 DBMS에 현재도 많이 쓰이는 관계 DBMS는 ( )단계에 해당한다.
#
# * 객체 성격과 관계 성격을 동반한 (       ) DBMS는 어쩌고
#
# * Non(   ) DBMS는 (   )을 사용하지 않는 DBMS로 관계 DBMS와 기본 철학이 다르다.
#
# * 메타 데이터는 1)데이터 관리 시스템이 생성하며, 2)일반 이용자는 검색만 가능하며, 같은 의미로는 시스템 데이터베이스, 데이터 사전 또는 시스템 (    )가 있다.
#
# * 데이터베이스의 스키마를 정의-변경-삭제하는 데이터 언어를 데이터 (    )라고 한다.
#
# * 데이터 모델링은 크게 (  ), 데이터 구조, 그리고 제약조건으로 구성된다.
#
# * 개체의 특성을 (   )이라 하며, 속성이 실제 값을 가지면 개체 (      )가 된다.
#
# * 속성은 일반적으로 의미있는 데이터의 가장 작은 (    ) 단위이다.
#
# * 속성은 단일값/다중값, 단순/복합, (   ) 속성으로 나뉜다.
#
# * 개체-관계 다이어그램에서 개체는 사각형, 관계는 (       ), 속성은 원으로 표시하며, 개체가 여러 개의 속성을 가진다는 것은 개체-관계 다이어그램에서 여러 개의 (  )을 가진다는 의미이다.
#
# * 아직 결정되지 않았거나 모르는 값을 (    )값이라고 한다.
#
# * 관게는 일대일 관계만을 고려하지 않고 (    ) 관계와 (    ) 관계를 고려하게 된다. 또한 관계에서 종속성이 존재한다면 이를 (   ) 마름모선으로 표시한다.
#
# * 고객이 반드시 구매를 하는 상황이라면 고객과 구매는 종속이지만 구매할 책이 존재하지 않는다면 구매와 책은 (   )이 아니다.
#
# * 개체-관계 다이어그램은 데이터베이스에 저장될 파일의 (     )에 대한 정보를 줄 수 있다.
#
# * 개체는 반드시 (    ) 실체일 필요는 없으며, 개념적 정의 사용이 가능하다.
#
# * 데이터 모델링은 크게 개념 모델링과 (   ) 모델링이 있다.
#
# * 릴레이션은 여러 개 존재할 수 있으며 각각의 릴레이션은 릴레이션 이름 (   ) 이름들로 구별된다.
#
# * 튜플의 유일성은 속성의 부분집합인 키로 구별되며, 이때 사용될 수 있는 키는 (    ), (    ), (    )가 있다.
#
# * 기본키는 (     )값을 가질 수 없으나, (   )키는 (    )값을 가질 수 있다.
#
# * 기본키와 외래키는 (    )이 같아야 하며, 만약에 기본키 중 특정값이 삭제된다면 그 값에 해당하는 외래키 값에 널값을 넣거나 해당 (   )을 삭제해야 한다.
#
# * 관계 데이터의 무결성을 위해서는 기본키가 (   )값을 가지면 안되며, 이를 위해서 (   )값에 대한 입력 자체를 제한해야 한다.
#
# * (      ) 제약조건은 외래키의 도메인과 기본키의 도메인을 일치시켜야 하는 제약조건이다.
#
# * 릴레이션에서 차수는 (      )를 카디널리티는 (      )를 의미한다.
#
# * 만약의 외래키의 값을 (   )하는 경우 참조 무결성 제약조건에 영향을 주게 된다.
